# %%
import stata_setup
import pandas as pd
stata_setup.config("/Applications/STATA","se")
# Out:
#   ___  ____  ____  ____  ____ ®
#  /__    /   ____/   /   ____/      17.0
# ___/   /   /___/   /   /___/       SE—Standard Edition
#
#  Statistics and Data Science       Copyright 1985-2021 StataCorp LLC
#                                    StataCorp
#                                    4905 Lakeway Drive
#                                    College Station, Texas 77845 USA
#                                    800-STATA-PC        https://www.stata.com
#                                    979-696-4600        stata@stata.com
#
# Stata license: Unlimited-user, expiring 31 Aug 2023
# Serial number: 401709320927
#   Licensed to: Bruno Komel
#                University of Pittsburgh
#
# Notes:
#       1. Unicode is supported; see help unicode_advice.
#       2. Maximum number of variables is set to 5,000 but can be increased;
#           see help set_maxvar.

# %%
# %%stata
#
#
# // We'll be using data from
#
# // The China Syndrome: Local Labor Market Effects of Import Competition in the United States
# // By Autor, Dorn, Hanson (2013)
# // https://www.aeaweb.org/articles?id=10.1257/aer.103.6.2121
#
# global ADH_derived https://github.com/zhangxiang0822/ShiftShareSEStata/raw/master/data/ADH_derived.dta
#
# use $ADH_derived, clear
#
# global controls t2 l_shind_manuf_cbp reg_encen reg_escen reg_midatl reg_mount reg_pacif reg_satl reg_wncen reg_wscen l_sh_popedu_c l_sh_popfborn l_sh_empl_f l_sh_routine33 l_task_outsource
#
# global controls2 t2 l_sh* reg_*
# Out:
# .
# .
# . // We'll be using data from
# .
# . // The China Syndrome: Local Labor Market Effects of Import Competition in th
# > e United States
# . // By Autor, Dorn, Hanson (2013)
# . // https://www.aeaweb.org/articles?id=10.1257/aer.103.6.2121
# .
# . global ADH_derived https://github.com/zhangxiang0822/ShiftShareSEStata/raw/ma
# > ster/data/ADH_derived.dta
#
# .
# . use $ADH_derived, clear
#
# .
# . global controls t2 l_shind_manuf_cbp reg_encen reg_escen reg_midatl reg_mount
# >  reg_pacif reg_satl reg_wncen reg_wscen l_sh_popedu_c l_sh_popfborn l_sh_empl
# > _f l_sh_routine33 l_task_outsource
#
# .
# . global controls2 t2 l_sh* reg_*
#
# .

# %%
# %%stata
#
# // ssc install ivreg_ss
# // ssc install reg_ss
# Out:
# .
# . // ssc install ivreg_ss
# . // ssc install reg_ss
# .

# %%
# %%stata
#
# // Just replicating column 1 and 7 of table 3 on the ADH 2013 paper
# ivreg2 d_sh_empl_mfg (d_tradeusch_pw=d_tradeotch_pw_lag) t2 [aw=weight], cluster(state) first
# Out:
# .
# . // Just replicating column 1 and 7 of table 3 on the ADH 2013 paper
# . ivreg2 d_sh_empl_mfg (d_tradeusch_pw=d_tradeotch_pw_lag) t2 [aw=weight], clus
# > ter(state) first
# (sum of wgt is     2.0000e+00)
#
# First-stage regressions
# -----------------------
#
#
# First-stage regression of d_tradeusch_pw:
#
# Statistics robust to heteroskedasticity and clustering on state
# Number of obs =                   1444
# Number of clusters (state) =        48
# ------------------------------------------------------------------------------
#              |               Robust
# d_tradeusc~w | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# d_tradeotc~g |   .7916466   .0801573     9.88   0.000     .6344092    .9488841
#           t2 |   .2368578   .1393049     1.70   0.089    -.0364042    .5101198
#        _cons |   .3457039   .0792717     4.36   0.000     .1902035    .5012043
# ...

# %%
# %%stata
#
# ivreg2 d_sh_empl_mfg (d_tradeusch_pw=d_tradeotch_pw_lag) $controls [aw=weight], cluster(state) first
# Out:
# .
# . ivreg2 d_sh_empl_mfg (d_tradeusch_pw=d_tradeotch_pw_lag) $controls [aw=weight
# > ], cluster(state) first
# (sum of wgt is     2.0000e+00)
#
# First-stage regressions
# -----------------------
#
#
# First-stage regression of d_tradeusch_pw:
#
# Statistics robust to heteroskedasticity and clustering on state
# Number of obs =                   1444
# Number of clusters (state) =        48
# ------------------------------------------------------------------------------
#              |               Robust
# d_tradeusc~w | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# d_tradeotc~g |   .6310409   .0914237     6.90   0.000     .4517016    .8103803
#           t2 |   .6332966   .1976986     3.20   0.001     .2454856    1.021108
# l_shind_ma~p |    .052753   .0111788     4.72   0.000     .0308244    .0746816
# ...

# %%
# %%stata
#
# help ivreg_ss
# Out:
# .
# . help ivreg_ss
#
#
# Title
# -----
#
#     ivreg_ss --  Computes confidence intervals, standard errors, and p-values
#                  in an IV regression in which the instrumental variable has a
#                  shift-share structure.
#
# Syntax
# ------
#
#     ivreg_ss depvar, endogenous_var(varname) shiftshare_iv(varname)
#                share_varlist(varlist) [control_varlist(varlist)
#                weight_var(varname) akmtype(#) beta0(#) path_cluster
#                cluster_var(varname) alpha(#) firststage(#)]
#
#     Options                       Description
#     -------------------------------------------------------------------------
#     Model
#     endogenous_var(varname)       Endogenous variable in the IV regression.
#     shiftshare_iv(varname)        Shift-share instrumental variable.
#     share_varlist(varlist)        List of variables containing the sector
#                                     shares. Each variable indicates the
# ...

# %%
# %%stata
#
# // Example 1
#
# ivreg_ss d_sh_empl_mfg, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeotch_pw_lag) ///
# control_varlist($controls) share_varlist(emp_share1-emp_share770) weight_var(weight) alpha(0.05) ///
# akmtype(1) firststage(1)
# Out:
# .
# . // Example 1
# .
# . ivreg_ss d_sh_empl_mfg, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeo
# > tch_pw_lag) ///
# > control_varlist($controls) share_varlist(emp_share1-emp_share770) weight_var(
# > weight) alpha(0.05) ///
# > akmtype(1) firststage(1)
#
# Below we show First-stage results
#
# The estimated coefficient is 0.6310
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.0273    0.0000    0.5775    0.6846
# EHW               0.0870    0.0000    0.4605    0.8016
# AKM               0.0693    0.0000    0.4952    0.7669
#
# Below we show IV regression results
# The estimated coefficient is -0.5964
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.0540    0.0000    -0.7021    -0.4906
# EHW               0.0952    0.0000    -0.7830    -0.4097
# AKM               0.1095    0.0000    -0.8110    -0.3817
#
# .

# %%
# %%stata
#
# // Example 2 (using the AKM0 model)
# use $ADH_derived, clear
#
# ivreg_ss d_sh_empl_mfg, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeotch_pw_lag) ///
# control_varlist($controls) share_varlist(emp_share1-emp_share770) weight_var(weight) akmtype(0) firststage(1)
# Out:
# .
# . // Example 2 (using the AKM0 model)
# . use $ADH_derived, clear
#
# .
# . ivreg_ss d_sh_empl_mfg, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeo
# > tch_pw_lag) ///
# > control_varlist($controls) share_varlist(emp_share1-emp_share770) weight_var(
# > weight) akmtype(0) firststage(1)
#
# Below we show First-stage results
#
# The estimated coefficient is 0.6310
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.0273    0.0000    0.5775    0.6846
# EHW               0.0870    0.0000    0.4605    0.8016
# AKM0              0.0938    0.0001    0.5220    0.8898
#
# Below we show IV regression results
# The estimated coefficient is -0.5964
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.0540    0.0000    -0.7021    -0.4906
# EHW               0.0952    0.0000    -0.7830    -0.4097
# AKM0              0.1275    0.0001    -0.8914    -0.3918
#
# .

# %%
# %%stata
#
#
# // Example 3 (now clustering at the sector level)
# use $ADH_derived, clear
#
# global cpath "https://github.com/zhangxiang0822/ShiftShareSEStata/raw/master/data/sector_derived.dta"
#
# ivreg_ss d_sh_empl_mfg, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeotch_pw_lag) ///
# control_varlist($controls2) share_varlist(emp_share1-emp_share770) weight_var(weight) akmtype(1) ///
# path_cluster(`cpath') cluster_var(sec_3d) firststage(1)
#
# use $cpath, clear
# Out:
# .
# .
# . // Example 3 (now clustering at the sector level)
# . use $ADH_derived, clear
#
# .
# . global cpath "https://github.com/zhangxiang0822/ShiftShareSEStata/raw/master/
# > data/sector_derived.dta"
#
# .
# . ivreg_ss d_sh_empl_mfg, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeo
# > tch_pw_lag) ///
# > control_varlist($controls2) share_varlist(emp_share1-emp_share770) weight_var
# > (weight) akmtype(1) ///
# > path_cluster(`cpath') cluster_var(sec_3d) firststage(1)
#
# Below we show First-stage results
# We're sorry that we don't support reporting first-stage results with clustering
# > . To obtain the correct clustered AKM standard errors, please use reg_ss comm
# > and to run first-stage regression manually.
#
# The estimated coefficient is 0.6329
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.0272    0.0000    0.5795    0.6862
# EHW               0.0873    0.0000    0.4618    0.8039
# ...

# %%
# %%stata
#
#
# // Example 4 (Using the AKM0 Model)
# use $ADH_derived, clear
#
# ivreg_ss d_sh_empl, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeotch_pw_lag) ///
# control_varlist($controls) share_varlist(emp_share1-emp_share770) weight_var(weight) akmtype(0) ///
# path_cluster(`cpath') cluster_var(sec_3d) firststage(1)
# Out:
# .
# .
# . // Example 4 (Using the AKM0 Model)
# . use $ADH_derived, clear
#
# .
# . ivreg_ss d_sh_empl, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeotch_
# > pw_lag) ///
# > control_varlist($controls) share_varlist(emp_share1-emp_share770) weight_var(
# > weight) akmtype(0) ///
# > path_cluster(`cpath') cluster_var(sec_3d) firststage(1)
#
# Below we show First-stage results
# We're sorry that we don't support reporting first-stage results with clustering
# > . To obtain the correct clustered AKM standard errors, please use reg_ss comm
# > and to run first-stage regression manually.
#
# The estimated coefficient is 0.6310
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.0273    0.0000    0.5775    0.6846
# EHW               0.0870    0.0000    0.4605    0.8016
# AKM0              0.0938    0.0001    0.5220    0.8898
#
# Below we show IV regression results
# The estimated coefficient is -0.7742
# Inference
# ...

# %%
# %%stata
#
#
# // Example 5 (clustering at the state level)
# use $ADH_derived, clear
#
# ivreg_ss d_sh_empl_mfg, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeotch_pw_lag) ///
# control_varlist($controls2) share_varlist(emp_share1-emp_share770) weight_var(weight) akmtype(1)  ///
# cluster_var(state) firststage(1)
# Out:
# .
# .
# . // Example 5 (clustering at the state level)
# . use $ADH_derived, clear
#
# .
# . ivreg_ss d_sh_empl_mfg, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeo
# > tch_pw_lag) control_varlist($controls2) share_varlist(emp_share1-emp_share770
# > ) weight_var(weight) akmtype(1)  cluster_var(state) firststage(1)
#
# Below we show First-stage results
# We're sorry that we don't support reporting first-stage results with clustering
# > . To obtain the correct clustered AKM standard errors, please use reg_ss comm
# > and to run first-stage regression manually.
#
# The estimated coefficient is 0.6329
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.0272    0.0000    0.5795    0.6862
# EHW               0.0873    0.0000    0.4618    0.8039
# AKM               0.0673    0.0000    0.5009    0.7649
#
# Below we show IV regression results
# The estimated coefficient is -0.5979
# Inference
# ...

# %%
# %%stata
#
# **************************************
# *                                    *
# *                                    *
# *              Exercise              *
# *                                    *
# *                                    *
# **************************************

# %%
# %%stata
#
# cd "/Users/brunokomel/Documents/Pitt/Year_2/TA - Econ 3080/Recitations/Recitation 10 - Shift-Share/Recitation 10 - Shift-Share - Handout"
# use "workfile_china.dta", clear
#
# keep lnchg_popworkage czone statefip yr t2
#
# egen id = concat(czone statefip yr t2)
# unique id
#
# save "workfile_china_id.dta", replace
#
# use $ADH_derived, clear
#
# egen id = concat(czone state year t2)
# unique id
#
# merge 1:1 id using "/Users/brunokomel/Documents/Pitt/Year_2/TA - Econ 3080/Recitations/Recitation 10 - Shift-Share/Recitation 10 - Shift-Share - Handout/workfile_china_id.dta"
#
# drop _merge id
# Out:
# .
# . cd "/Users/brunokomel/Documents/Pitt/Year_2/TA - Econ 3080/Recitations/Recita
# > tion 10 - Shift-Share/Recitation 10 - Shift-Share - Handout"
# /Users/brunokomel/Documents/Pitt/Year_2/TA - Econ 3080/Recitations/Recitation 1
# > 0 - Shift-Share/Recitation 10 - Shift-Share - Handout
#
# . use "workfile_china.dta", clear
#
# .
# . keep lnchg_popworkage czone statefip yr t2
#
# .
# . egen id = concat(czone statefip yr t2)
#
# . unique id
# Number of unique values of id is  1444
# Number of records is  1444
#
# .
# . save "workfile_china_id.dta", replace
# file workfile_china_id.dta saved
#
# .
# . use $ADH_derived, clear
#
# .
# . egen id = concat(czone state year t2)
#
# . unique id
# Number of unique values of id is  1444
# Number of records is  1444
#
# .
# . merge 1:1 id using "/Users/brunokomel/Documents/Pitt/Year_2/TA - Econ 3080/Re
# > citations/Recitation 10 - Shift-Share/Recitation 10 - Shift-Share - Handout/w
# > orkfile_china_id.dta"
# ...

# %%
# %%stata
#
# * Exercise: Replicate the first coefficient in table 4 using both the ivreg2 and the ivreg_ss command
# * Note, the outcome of interest now is lnchg_popworkage
# Out:
# .
# . * Exercise: Replicate the first coefficient in table 4 using both the ivreg2
# > and the ivreg_ss command
# . * Note, the outcome of interest now is lnchg_popworkage
# .

# %%
# %%stata
#
# ivreg2  lnchg_popworkage (d_tradeusch_pw=d_tradeotch_pw_lag) t2 [aw=weight], cluster(state) first
# Out:
# .
# . ivreg2  lnchg_popworkage (d_tradeusch_pw=d_tradeotch_pw_lag) t2 [aw=weight],
# > cluster(state) first
# (sum of wgt is     1.0803e+00)
#
# First-stage regressions
# -----------------------
#
#
# First-stage regression of d_tradeusch_pw:
#
# Statistics robust to heteroskedasticity and clustering on state
# Number of obs =                    770
# Number of clusters (state) =        37
# ------------------------------------------------------------------------------
#              |               Robust
# d_tradeusc~w | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
# d_tradeotc~g |   .7835072   .1360029     5.76   0.000     .5165252    1.050489
#           t2 |   .2558367   .2204254     1.16   0.246     -.176872    .6885453
#        _cons |   .0235051   .0082742     2.84   0.005     .0072623    .0397479
# ------------------------------------------------------------------------------
# ...

# %%
# %%stata
#
# ivreg_ss lnchg_popworkage, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tradeotch_pw_lag) ///
# control_varlist(t2) share_varlist(emp_share1-emp_share770) weight_var(weight) cluster_var(statefip) ///
# firststage(1)
# Out:
# .
# . ivreg_ss lnchg_popworkage, endogenous_var(d_tradeusch_pw) shiftshare_iv(d_tra
# > deotch_pw_lag) ///
# > control_varlist(t2) share_varlist(emp_share1-emp_share770) weight_var(weight)
# >  cluster_var(statefip) ///
# > firststage(1)
#
# Below we show First-stage results
# We're sorry that we don't support reporting first-stage results with clustering
# > . To obtain the correct clustered AKM standard errors, please use reg_ss comm
# > and to run first-stage regression manually.
#
# The estimated coefficient is 0.7916
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.0234    0.0000    0.7458    0.8375
# EHW               0.0787    0.0000    0.6373    0.9460
# AKM               0.0667    0.0000    0.6608    0.9225
#
# Below we show IV regression results
# The estimated coefficient is -1.0306
# Inference
#                Std. Error   p-value   Lower CI   Upper CI
# Homoscedastic     0.2318    0.0000    -1.4848    -0.5763
# ...
