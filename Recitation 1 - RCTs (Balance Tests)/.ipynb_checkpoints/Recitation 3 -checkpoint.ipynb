// %% [markdown]
// Install randomize package
// ssc install randomize

// %% [markdown]
// # Miguel & Kremer

// %% [markdown]
// First example: From Miguel & Kremer (ECTA, 2004) //
//
// Note: You can obtain the dataset and replication code from https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/28038. The .dta file namelist is needed for this exercise.

// %% [markdown]
// Remember to set your working directory correctly using the "cd..." command

// %%
cd "~/Documents/Pitt/Year_2/TA - Econ 3080/Recitations/Recitation 3"
// Out:
// /Users/brunokomel/Documents/Pitt/Year_2/TA - Econ 3080/Recitations/Recitation 3

// %%
* Start with Namelist data
use namelist.dta, clear 

* Each school is a distinct data point, weighted by number of pupils
    keep if visit==981 
    collapse sex elg98 stdgap yrbirth wgrp* (count) np=pupid, by (sch98v1)
// Out:
// (521,880 observations deleted)

// %%
**** TABLE 1: PANEL A
bys wgrp: summ sex elg98 stdgap yrbirth [aw=np] //bysort treatment group, summarise these variables 

foreach var in sex elg98 stdgap yrbirth { 
    regress `var' wgrp1 wgrp2 [aw=np] 
} 

bys wgrp: summ sex elg98 stdgap yrbirth [aw=np]
// Out:
// --------------------------------------------------------------------------------
// -> wgrp = 1
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11639    .5330215   .0274975   .4649681        .58
//        elg98 |      25       11639     .885924   .0247143   .8320313   .9418604
//       stdgap |      25       11639   -1.972652   .2533067  -2.605882  -1.580786
//      yrbirth |      25       11639    1986.192   .5346503   1985.256   1987.464
//
// --------------------------------------------------------------------------------
// -> wgrp = 2
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11995    .5095843   .1047281   .0200893   .5714286
//        elg98 |      25       11995    .8919841    .024791   .8363096          1
//       stdgap |      25       11995   -1.822477   .3956333  -2.539063  -.7777778
//      yrbirth |      25       11995    1986.542   .6205696   1985.349   1988.789
//
// --------------------------------------------------------------------------------
// -> wgrp = 3
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11158    .5221577   .0213547   .4585635   .5606061
//        elg98 |      25       11158    .8842172   .0199678        .84   .9104478
//       stdgap |      25       11158    -1.96956    .335091  -2.612903  -1.384921
//      yrbirth |      25       11158    1985.787   .5751849   1984.777   1986.964
//
//
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      0.84
//        Model |  .007012123         2  .003506062   Prob > F        =    0.4365
//     Residual |  .300999144        72  .004180544   R-squared       =    0.0228
// -------------+----------------------------------   Adj R-squared   =   -0.0044
//        Total |  .308011268        74  .004162314   Root MSE        =    .06466
//
// ------------------------------------------------------------------------------
//          sex | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |   .0108639   .0184507     0.59   0.558    -.0259169    .0476447
//        wgrp2 |  -.0125733   .0183162    -0.69   0.495     -.049086    .0239394
//        _cons |   .5221577   .0131835    39.61   0.000     .4958767    .5484386
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      0.77
//        Model |  .000841356         2  .000420678   Prob > F        =    0.4653
//     Residual |  .039174487        72   .00054409   R-squared       =    0.0210
// -------------+----------------------------------   Adj R-squared   =   -0.0062
//        Total |  .040015843        74  .000540755   Root MSE        =    .02333
//
// ------------------------------------------------------------------------------
//        elg98 | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |   .0017069   .0066563     0.26   0.798    -.0115622    .0149759
//        wgrp2 |   .0077669   .0066078     1.18   0.244    -.0054054    .0209393
//        _cons |   .8842172   .0047561   185.91   0.000     .8747361    .8936983
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      1.68
//        Model |  .374551628         2  .187275814   Prob > F        =    0.1935
//     Residual |  8.02368227        72  .111440031   R-squared       =    0.0446
// -------------+----------------------------------   Adj R-squared   =    0.0181
//        Total |   8.3982339        74  .113489647   Root MSE        =    .33383
//
// ------------------------------------------------------------------------------
//       stdgap | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |  -.0030915   .0952615    -0.03   0.974    -.1929918    .1868089
//        wgrp2 |   .1470828   .0945671     1.56   0.124    -.0414332    .3355989
//        _cons |   -1.96956    .068067   -28.94   0.000    -2.105249   -1.833871
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =     10.63
//        Model |  7.10907992         2  3.55453996   Prob > F        =    0.0001
//     Residual |  24.0838656        72  .334498133   R-squared       =    0.2279
// -------------+----------------------------------   Adj R-squared   =    0.2065
//        Total |  31.1929455        74   .42152629   Root MSE        =    .57836
//
// ------------------------------------------------------------------------------
//      yrbirth | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |    .404556   .1650417     2.45   0.017     .0755514    .7335607
//        wgrp2 |   .7551539   .1638386     4.61   0.000     .4285476     1.08176
//        _cons |   1985.787   .1179269  1.7e+04   0.000     1985.552    1986.022
// ------------------------------------------------------------------------------
//
//
// --------------------------------------------------------------------------------
// -> wgrp = 1
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11639    .5330215   .0274975   .4649681        .58
//        elg98 |      25       11639     .885924   .0247143   .8320313   .9418604
//       stdgap |      25       11639   -1.972652   .2533067  -2.605882  -1.580786
//      yrbirth |      25       11639    1986.192   .5346503   1985.256   1987.464
//
// --------------------------------------------------------------------------------
// -> wgrp = 2
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11995    .5095843   .1047281   .0200893   .5714286
//        elg98 |      25       11995    .8919841    .024791   .8363096          1
//       stdgap |      25       11995   -1.822477   .3956333  -2.539063  -.7777778
//      yrbirth |      25       11995    1986.542   .6205696   1985.349   1988.789
//
// --------------------------------------------------------------------------------
// -> wgrp = 3
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11158    .5221577   .0213547   .4585635   .5606061
//        elg98 |      25       11158    .8842172   .0199678        .84   .9104478
//       stdgap |      25       11158    -1.96956    .335091  -2.612903  -1.384921
//      yrbirth |      25       11158    1985.787   .5751849   1984.777   1986.964

// %%
randomize, groups(3) generate(grp)

*Note: We can check the balance of this grp variable as follows: 
bys grp: summ sex elg98 stdgap yrbirth [aw=np] //bysort treatment group, summarise these variables 

gen grp1 = (grp == 1) //creating dummies for each group category
gen grp2 = (grp == 2)

foreach var in sex elg98 stdgap yrbirth { 
	regress `var' grp1 grp2 [aw=np] 
}
// Out:
// Randomizing 75 records.
// Error in the manova test.
//
// Assignment results:
//
//         grp |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |         25       33.33       33.33
//           2 |         25       33.33       66.67
//           3 |         25       33.33      100.00
// ------------+-----------------------------------
//       Total |         75      100.00
//
// Review balance:
//
// Multinomial logistic regression                         Number of obs =     75
//                                                         LR chi2(0)    =   0.00
//                                                         Prob > chi2   =      .
// Log likelihood = -82.395922                             Pseudo R2     = 0.0000
//
// ------------------------------------------------------------------------------
//          grp | Coefficient  Std. err.      z    P>|z|     [95% conf. interval]
// -------------+----------------------------------------------------------------
// 1            |  (base outcome)
// -------------+----------------------------------------------------------------
// 2            |
//        _cons |  -1.54e-15   .2828427    -0.00   1.000    -.5543615    .5543615
// -------------+----------------------------------------------------------------
// 3            |
//        _cons |  -1.72e-15   .2828427    -0.00   1.000    -.5543615    .5543615
// ------------------------------------------------------------------------------
//
// Assignment results:
//
//         grp |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |         25       33.33       33.33
//           2 |         25       33.33       66.67
//           3 |         25       33.33      100.00
// ------------+-----------------------------------
//       Total |         75      100.00
//
//
// --------------------------------------------------------------------------------
// -> grp = 1
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       13550     .506904   .0976993   .0200893   .5576324
//        elg98 |      25       13550    .8870235   .0265163   .8363096          1
//       stdgap |      25       13550   -1.833232    .319813  -2.564189  -.7777778
//      yrbirth |      25       13550    1986.203   .7184555   1985.166   1988.789
//
// --------------------------------------------------------------------------------
// -> grp = 2
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       10692    .5290909   .0279765   .4649681        .58
//        elg98 |      25       10692     .887954   .0243088   .8320313   .9418604
//       stdgap |      25       10692   -2.034666   .3499238  -2.612903  -1.443956
//      yrbirth |      25       10692    1986.171   .7249666   1984.777    1987.66
//
// --------------------------------------------------------------------------------
// -> grp = 3
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       10550    .5324121   .0241936   .4585635   .5742574
//        elg98 |      25       10550    .8875395   .0181772   .8527919    .979798
//       stdgap |      25       10550   -1.914855   .3243836  -2.605882  -1.402564
//      yrbirth |      25       10550    1986.168    .481878   1985.467   1987.178
//
//
//
//
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      1.24
//        Model |  .010258789         2  .005129395   Prob > F        =    0.2954
//     Residual |  .297752478        72  .004135451   R-squared       =    0.0333
// -------------+----------------------------------   Adj R-squared   =    0.0065
//        Total |  .308011268        74  .004162314   Root MSE        =    .06431
//
// ------------------------------------------------------------------------------
//          sex | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//         grp1 |  -.0255081   .0179839    -1.42   0.160    -.0613583    .0103421
//         grp2 |  -.0033212    .019007    -0.17   0.862    -.0412109    .0345684
//        _cons |   .5324121   .0134848    39.48   0.000     .5055307    .5592936
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      0.01
//        Model |  .000011332         2  5.6661e-06   Prob > F        =    0.9899
//     Residual |  .040004511        72  .000555618   R-squared       =    0.0003
// -------------+----------------------------------   Adj R-squared   =   -0.0275
//        Total |  .040015843        74  .000540755   Root MSE        =    .02357
//
// ------------------------------------------------------------------------------
//        elg98 | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//         grp1 |   -.000516   .0065919    -0.08   0.938    -.0136567    .0126247
//         grp2 |   .0004146   .0069669     0.06   0.953    -.0134737    .0143028
//        _cons |   .8875395   .0049428   179.56   0.000     .8776862    .8973927
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      2.39
//        Model |  .523556519         2   .26177826   Prob > F        =    0.0985
//     Residual |  7.87467738        72  .109370519   R-squared       =    0.0623
// -------------+----------------------------------   Adj R-squared   =    0.0363
//        Total |   8.3982339        74  .113489647   Root MSE        =    .33071
//
// ------------------------------------------------------------------------------
//       stdgap | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//         grp1 |    .081623   .0924851     0.88   0.380    -.1027428    .2659887
//         grp2 |  -.1198112   .0977465    -1.23   0.224    -.3146653    .0750429
//        _cons |  -1.914855   .0693478   -27.61   0.000    -2.053097   -1.776612
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      0.02
//        Model |  .020002928         2  .010001464   Prob > F        =    0.9772
//     Residual |  31.1729425        72  .432957535   R-squared       =    0.0006
// -------------+----------------------------------   Adj R-squared   =   -0.0271
//        Total |  31.1929455        74   .42152629   Root MSE        =      .658
//
// ------------------------------------------------------------------------------
//      yrbirth | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//         grp1 |   .0347892   .1840112     0.19   0.851    -.3320305    .4016089
//         grp2 |   .0027201   .1944794     0.01   0.989    -.3849676    .3904078
//        _cons |   1986.168   .1379766  1.4e+04   0.000     1985.893    1986.444
// ------------------------------------------------------------------------------

// %%
// Another example: sysuse nlsw88 // 
clear
sysuse nlsw88.dta //another preloaded dataset (similar to auto.dta), but from the National Longitudinal Survey of Women in 88. 

gen black = (race == 2)

randomize, groups(2) generate(grp)
bysort grp: sum age black married collgrad 

randomize, groups(2) block(black) generate(grp_alt)
bysort grp_alt: sum age black married collgrad
// Out:
// (NLSW, 1988 extract)
//
//
// Randomizing 2246 records.
// Error in the manova test.
//
// Assignment results:
//
//         grp |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |      1,123       50.00       50.00
//           2 |      1,123       50.00      100.00
// ------------+-----------------------------------
//       Total |      2,246      100.00
//
// Review balance:
//
// Multinomial logistic regression                        Number of obs =   2,246
//                                                        LR chi2(0)    =   -0.00
//                                                        Prob > chi2   =       .
// Log likelihood = -1556.8086                            Pseudo R2     = -0.0000
//
// ------------------------------------------------------------------------------
//          grp | Coefficient  Std. err.      z    P>|z|     [95% conf. interval]
// -------------+----------------------------------------------------------------
// 1            |  (base outcome)
// -------------+----------------------------------------------------------------
// 2            |
//        _cons |          0   .0422012     0.00   1.000    -.0827129    .0827129
// ------------------------------------------------------------------------------
//
// Assignment results:
//
//         grp |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |      1,123       50.00       50.00
//           2 |      1,123       50.00      100.00
// ------------+-----------------------------------
//       Total |      2,246      100.00
//
//
// --------------------------------------------------------------------------------
// -> grp = 1
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//          age |      1,123    39.07391    3.085367         34         46
//        black |      1,123    .2573464    .4373666          0          1
//      married |      1,123    .6393589    .4804005          0          1
//     collgrad |      1,123    .2439893    .4296777          0          1
//
// --------------------------------------------------------------------------------
// -> grp = 2
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//          age |      1,123    39.23241    3.033729         34         46
//        black |      1,123    .2617988    .4398095          0          1
//      married |      1,123    .6447017    .4788168          0          1
//     collgrad |      1,123    .2297418    .4208541          0          1
//
//
// Block breakdown:
//
// group(black |
//           ) |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           0 |      1,663       74.04       74.04
//           1 |        583       25.96      100.00
// ------------+-----------------------------------
//       Total |      2,246      100.00
// Randomizing block 1 with 1663 records.
// Error in the manova test.
//
// Assignment results for block 1:
//
//     grp_alt |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |        831       49.97       49.97
//           2 |        832       50.03      100.00
// ------------+-----------------------------------
//       Total |      1,663      100.00
//
// Review balance within block 1:
//
// Multinomial logistic regression                         Number of obs =  1,663
//                                                         LR chi2(0)    =   0.00
//                                                         Prob > chi2   =      .
// Log likelihood = -1152.7035                             Pseudo R2     = 0.0000
//
// ------------------------------------------------------------------------------
//      grp_alt | Coefficient  Std. err.      z    P>|z|     [95% conf. interval]
// -------------+----------------------------------------------------------------
// 1            |  (base outcome)
// -------------+----------------------------------------------------------------
// 2            |
//        _cons |   .0012026   .0490438     0.02   0.980    -.0949214    .0973267
// ------------------------------------------------------------------------------
// Randomizing block 2 with 583 records.
// Error in the manova test.
//
// Assignment results for block 2:
//
//     grp_alt |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |        292       50.09       50.09
//           2 |        291       49.91      100.00
// ------------+-----------------------------------
//       Total |        583      100.00
//
// Review balance within block 2:
//
// Multinomial logistic regression                         Number of obs =    583
//                                                         LR chi2(0)    =   0.00
//                                                         Prob > chi2   =      .
// Log likelihood = -404.10395                             Pseudo R2     = 0.0000
//
// ------------------------------------------------------------------------------
//      grp_alt | Coefficient  Std. err.      z    P>|z|     [95% conf. interval]
// -------------+----------------------------------------------------------------
// 1            |  (base outcome)
// -------------+----------------------------------------------------------------
// 2            |
//        _cons |  -.0034305   .0828317    -0.04   0.967    -.1657776    .1589165
// ------------------------------------------------------------------------------
//
// Assignment results:
//
//     grp_alt |      Freq.     Percent        Cum.
// ------------+-----------------------------------
//           1 |      1,123       50.00       50.00
//           2 |      1,123       50.00      100.00
// ------------+-----------------------------------
//       Total |      2,246      100.00
//
//
// --------------------------------------------------------------------------------
// -> grp_alt = 1
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//          age |      1,123     39.0837    3.064973         34         46
//        black |      1,123    .2600178    .4388394          0          1
//      married |      1,123    .6482636     .477725          0          1
//     collgrad |      1,123    .2368655    .4253485          0          1
//
// --------------------------------------------------------------------------------
// -> grp_alt = 2
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//          age |      1,123    39.22262    3.054809         34         45
//        black |      1,123    .2591273    .4383508          0          1
//      married |      1,123     .635797    .4814204          0          1
//     collgrad |      1,123    .2368655    .4253485          0          1

// %% [markdown]
// # RAND Experiment

// %%
use rand_initial_sample_2.dta, clear


* Plan types:
/* 
	Plan type 1 = "Free plan"
	Plan type 2 = "Deductible plan"
	Plan type 3 = "Coinsurance plan"
	Plan type 4 = "Catastrophic plan" or "No Insurance"
*/

// %%
* Create means for catastrophic plan
matrix means_sd = J(11, 2, .)
local row = 1

foreach var of varlist female blackhisp age educper income1cpi hosp ghindx cholest systol mhi {
	summarize `var' if plantype == 4
	matrix means_sd[`row', 1] = r(mean)
	matrix means_sd[`row', 2] = r(sd)
	local row = `row'+1
}

count if plantype_4 == 1
matrix means_sd[11, 1] = r(N)

matrix rownames means_sd = female blackhisp age educper income1cpi hosp ghindx cholest systol mhi plantype
matrix list means_sd

#d ;
frmttable, statmat(means_sd) substat(1) varlabels sdec(4)
		   ctitle("", "Cata. mean") replace;
#d cr
// Out:
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//       female |        759    .5599473    .4967206          0          1
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//    blackhisp |        600    .1716667    .3774051          0          1
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//          age |        759      32.361    12.92331         14         62
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//      educper |        663    12.10483    2.881461          1         22
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//   income1cpi |        716    31603.21    18148.25          0   89132.16
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//         hosp |        755    .1152318    .3195131          0          1
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//       ghindx |        531    70.85932    14.91117        5.7        100
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//      cholest |        427    207.3021    39.92446        113        380
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//       systol |        433    122.3418    16.47623         86        182
//
//     Variable |        Obs        Mean    Std. dev.       Min        Max
// -------------+---------------------------------------------------------
//          mhi |        722    73.84584    14.25083       24.5       99.5
//
//   759
//
//
//
//
// means_sd[11,2]
//                    c1         c2
//     female   .5599473  .49672064
//  blackhisp  .17166667   .3774051
//        age  32.361001  12.923312
//    educper  12.104827  2.8814608
// income1cpi  31603.207  18148.254
//       hosp  .11523179  .31951313
//     ghindx  70.859322  14.911167
//    cholest  207.30211   39.92446
//     systol   122.3418  16.476232
//        mhi  73.845845  14.250833
//   plantype        759          .
//
//
//                --------------------------------------------------
//                                                    Cata. mean
//                --------------------------------------------------
//                 Female                               0.5599
//                                                     (0.4967)
//                 Nonwhite                             0.1717
//                                                     (0.3774)
//                 Age                                  32.3610
//                                                     (12.9233)
//                 Education                            12.1048
//                                                     (2.8815)
//                 Family Income                      31,603.2072
//                                                   (18,148.2536)
//                 Hospitalized last year               0.1152
//                                                     (0.3195)
//                 General health index                 70.8593
//                                                     (14.9112)
//                 Cholesterol (mg/dl)                 207.3021
//                                                     (39.9245)
//                 Systolic blood pressure (mm Hg)     122.3418
//                                                     (16.4762)
//                 Mental health index                  73.8458
//                                                     (14.2508)
//                 Number enrolled                     759.0000
//
//                --------------------------------------------------

// %%
* Create regression output
* Column 2: Deductible plan compared to catastrophic plan
matrix deduct_diff = J(11, 2, .)
local row = 1

foreach var of varlist female blackhisp age educper income1cpi hosp ghindx cholest systol mhi {
	reg `var' plantype_1 plantype_2 plantype_3, cl(famid)
	matrix deduct_diff[`row', 1] = _b[plantype_2]
	matrix deduct_diff[`row', 2] = _se[plantype_2]
	local row = `row'+1
}
count if plantype_2 == 1
matrix deduct_diff[11, 1] = r(N)

#d ;
frmttable, statmat(deduct_diff) varlabels sdec(4)
		   ctitle("Deduct - cata.") substat(1) merge;
#d cr
// Out:
// Linear regression                               Number of obs     =      3,957
//                                                 F(3, 1982)        =       2.14
//                                                 Prob > F          =     0.0935
//                                                 R-squared         =     0.0007
//                                                 Root MSE          =     .49878
//
//                               (Std. err. adjusted for 1,983 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       female | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.0379396   .0149991    -2.53   0.012    -.0673552   -.0085239
//   plantype_2 |  -.0230574   .0160171    -1.44   0.150    -.0544694    .0083546
//   plantype_3 |  -.0247223    .015326    -1.61   0.107     -.054779    .0053345
//        _cons |   .5599473   .0117928    47.48   0.000     .5368198    .5830748
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,131
//                                                 F(3, 1966)        =       0.51
//                                                 Prob > F          =     0.6757
//                                                 R-squared         =     0.0009
//                                                 Root MSE          =      .3585
//
//                               (Std. err. adjusted for 1,967 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//    blackhisp | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.0280873   .0245338    -1.14   0.252    -.0762023    .0200277
//   plantype_2 |  -.0187915   .0265551    -0.71   0.479    -.0708705    .0332875
//   plantype_3 |   -.026914   .0249592    -1.08   0.281    -.0758632    .0220353
//        _cons |   .1716667   .0198612     8.64   0.000     .1327154     .210618
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,956
//                                                 F(3, 1982)        =       0.74
//                                                 Prob > F          =     0.5261
//                                                 R-squared         =     0.0006
//                                                 Root MSE          =     13.199
//
//                               (Std. err. adjusted for 1,983 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//          age | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .4349801   .6139501     0.71   0.479    -.7690751    1.639035
//   plantype_2 |   .5606786   .6758793     0.83   0.407      -.76483    1.886187
//   plantype_3 |   .9658089    .654734     1.48   0.140    -.3182304    2.249848
//        _cons |     32.361   .4849485    66.73   0.000     31.40994    33.31206
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,468
//                                                 F(3, 1975)        =       0.83
//                                                 Prob > F          =     0.4753
//                                                 R-squared         =     0.0012
//                                                 Root MSE          =     2.9817
//
//                               (Std. err. adjusted for 1,976 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//      educper | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.2627213   .1827742    -1.44   0.151    -.6211718    .0957292
//   plantype_2 |  -.1567911   .1908755    -0.82   0.411    -.5311296    .2175475
//   plantype_3 |  -.0612511   .1855042    -0.33   0.741    -.4250557    .3025534
//        _cons |   12.10483   .1400629    86.42   0.000     11.83014    12.37951
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,742
//                                                 F(3, 1883)        =       2.21
//                                                 Prob > F          =     0.0851
//                                                 R-squared         =     0.0041
//                                                 Root MSE          =      17425
//
//                               (Std. err. adjusted for 1,884 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//   income1cpi | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -976.1847   1344.553    -0.73   0.468    -3613.154    1660.785
//   plantype_2 |  -2104.385   1383.691    -1.52   0.128    -4818.115    609.3439
//   plantype_3 |    969.759   1389.015     0.70   0.485    -1754.411    3693.929
//        _cons |   31603.21   1071.181    29.50   0.000     29502.38    33704.03
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,932
//                                                 F(3, 1976)        =       0.08
//                                                 Prob > F          =     0.9720
//                                                 R-squared         =     0.0001
//                                                 Root MSE          =     .32034
//
//                               (Std. err. adjusted for 1,977 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//         hosp | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .0011745     .01458     0.08   0.936    -.0274192    .0297682
//   plantype_2 |   .0044946   .0160062     0.28   0.779    -.0268962    .0358853
//   plantype_3 |  -.0024867   .0151651    -0.16   0.870    -.0322279    .0272546
//        _cons |   .1152318    .011646     9.89   0.000     .0923921    .1380714
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,040
//                                                 F(3, 1557)        =       1.97
//                                                 Prob > F          =     0.1166
//                                                 R-squared         =     0.0024
//                                                 Root MSE          =     14.998
//
//                               (Std. err. adjusted for 1,558 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       ghindx | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -1.306369   .8708148    -1.50   0.134    -3.014463    .4017239
//   plantype_2 |  -1.440789   .9504384    -1.52   0.130    -3.305063    .4234851
//   plantype_3 |   .2106351   .9204692     0.23   0.819    -1.594855    2.016125
//        _cons |   70.85932   .6931129   102.23   0.000     69.49979    72.21886
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      2,254
//                                                 F(3, 1175)        =       1.38
//                                                 Prob > F          =     0.2481
//                                                 R-squared         =     0.0022
//                                                 Root MSE          =     42.872
//
//                               (Std. err. adjusted for 1,176 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//      cholest | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -5.246336   2.701373    -1.94   0.052    -10.54639    .0537178
//   plantype_2 |  -1.420108    2.98409    -0.48   0.634    -7.274848    4.434632
//   plantype_3 |  -1.931604   2.758279    -0.70   0.484    -7.343305    3.480097
//        _cons |   207.3021   1.990889   104.13   0.000      203.396    211.2082
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      2,292
//                                                 F(3, 1193)        =       1.37
//                                                 Prob > F          =     0.2494
//                                                 R-squared         =     0.0021
//                                                 Root MSE          =     16.577
//
//                               (Std. err. adjusted for 1,194 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       systol | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   1.123672   1.008422     1.11   0.265     -.854806     3.10215
//   plantype_2 |   2.323561     1.1545     2.01   0.044     .0584845    4.588637
//   plantype_3 |   .9073152   1.075802     0.84   0.399    -1.203359     3.01799
//        _cons |   122.3418   .8037472   152.21   0.000     120.7649    123.9187
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,817
//                                                 F(3, 1940)        =       1.46
//                                                 Prob > F          =     0.2228
//                                                 R-squared         =     0.0016
//                                                 Root MSE          =     13.846
//
//                               (Std. err. adjusted for 1,941 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//          mhi | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .8900588   .7652742     1.16   0.245    -.6107875    2.390905
//   plantype_2 |  -.1201439       .821    -0.15   0.884    -1.730279    1.489991
//   plantype_3 |   1.189266   .8094931     1.47   0.142    -.3983018    2.776834
//        _cons |   73.84584   .6181913   119.45   0.000     72.63346    75.05823
// ------------------------------------------------------------------------------
//
//   881
//
//
//
//        ------------------------------------------------------------------
//                                            Cata. mean    Deduct - cata.
//        ------------------------------------------------------------------
//         Female                               0.5599         -0.0231
//                                             (0.4967)        (0.0160)
//         Nonwhite                             0.1717         -0.0188
//                                             (0.3774)        (0.0266)
//         Age                                  32.3610         0.5607
//                                             (12.9233)       (0.6759)
//         Education                            12.1048        -0.1568
//                                             (2.8815)        (0.1909)
//         Family Income                      31,603.2072    -2,104.3855
//                                           (18,148.2536)   (1,383.6913)
//         Hospitalized last year               0.1152          0.0045
//                                             (0.3195)        (0.0160)
//         General health index                 70.8593        -1.4408
//                                             (14.9112)       (0.9504)
//         Cholesterol (mg/dl)                 207.3021        -1.4201
//                                             (39.9245)       (2.9841)
//         Systolic blood pressure (mm Hg)     122.3418         2.3236
//                                             (16.4762)       (1.1545)
//         Mental health index                  73.8458        -0.1201
//                                             (14.2508)       (0.8210)
//         Number enrolled                     759.0000        881.0000
//
//        ------------------------------------------------------------------

// %%
* Column 3: Coinsurance plan compared to catastrophic plan
matrix coins_diff = J(11, 2, .)
local row = 1

foreach var of varlist female blackhisp age educper income1cpi hosp ghindx cholest systol mhi {
	reg `var' plantype_1 plantype_2 plantype_3, cl(famid)
	matrix coins_diff[`row', 1] = _b[plantype_3]
	matrix coins_diff[`row', 2] = _se[plantype_3]
	local row = `row'+1
}

count if plantype_3 == 1
matrix coins_diff[11, 1] = r(N)

#d ;
frmttable, statmat(coins_diff) varlabels sdec(4)
		   ctitle("Coins - cata") substat(1) merge;
#d cr
// Out:
// Linear regression                               Number of obs     =      3,957
//                                                 F(3, 1982)        =       2.14
//                                                 Prob > F          =     0.0935
//                                                 R-squared         =     0.0007
//                                                 Root MSE          =     .49878
//
//                               (Std. err. adjusted for 1,983 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       female | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.0379396   .0149991    -2.53   0.012    -.0673552   -.0085239
//   plantype_2 |  -.0230574   .0160171    -1.44   0.150    -.0544694    .0083546
//   plantype_3 |  -.0247223    .015326    -1.61   0.107     -.054779    .0053345
//        _cons |   .5599473   .0117928    47.48   0.000     .5368198    .5830748
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,131
//                                                 F(3, 1966)        =       0.51
//                                                 Prob > F          =     0.6757
//                                                 R-squared         =     0.0009
//                                                 Root MSE          =      .3585
//
//                               (Std. err. adjusted for 1,967 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//    blackhisp | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.0280873   .0245338    -1.14   0.252    -.0762023    .0200277
//   plantype_2 |  -.0187915   .0265551    -0.71   0.479    -.0708705    .0332875
//   plantype_3 |   -.026914   .0249592    -1.08   0.281    -.0758632    .0220353
//        _cons |   .1716667   .0198612     8.64   0.000     .1327154     .210618
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,956
//                                                 F(3, 1982)        =       0.74
//                                                 Prob > F          =     0.5261
//                                                 R-squared         =     0.0006
//                                                 Root MSE          =     13.199
//
//                               (Std. err. adjusted for 1,983 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//          age | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .4349801   .6139501     0.71   0.479    -.7690751    1.639035
//   plantype_2 |   .5606786   .6758793     0.83   0.407      -.76483    1.886187
//   plantype_3 |   .9658089    .654734     1.48   0.140    -.3182304    2.249848
//        _cons |     32.361   .4849485    66.73   0.000     31.40994    33.31206
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,468
//                                                 F(3, 1975)        =       0.83
//                                                 Prob > F          =     0.4753
//                                                 R-squared         =     0.0012
//                                                 Root MSE          =     2.9817
//
//                               (Std. err. adjusted for 1,976 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//      educper | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.2627213   .1827742    -1.44   0.151    -.6211718    .0957292
//   plantype_2 |  -.1567911   .1908755    -0.82   0.411    -.5311296    .2175475
//   plantype_3 |  -.0612511   .1855042    -0.33   0.741    -.4250557    .3025534
//        _cons |   12.10483   .1400629    86.42   0.000     11.83014    12.37951
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,742
//                                                 F(3, 1883)        =       2.21
//                                                 Prob > F          =     0.0851
//                                                 R-squared         =     0.0041
//                                                 Root MSE          =      17425
//
//                               (Std. err. adjusted for 1,884 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//   income1cpi | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -976.1847   1344.553    -0.73   0.468    -3613.154    1660.785
//   plantype_2 |  -2104.385   1383.691    -1.52   0.128    -4818.115    609.3439
//   plantype_3 |    969.759   1389.015     0.70   0.485    -1754.411    3693.929
//        _cons |   31603.21   1071.181    29.50   0.000     29502.38    33704.03
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,932
//                                                 F(3, 1976)        =       0.08
//                                                 Prob > F          =     0.9720
//                                                 R-squared         =     0.0001
//                                                 Root MSE          =     .32034
//
//                               (Std. err. adjusted for 1,977 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//         hosp | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .0011745     .01458     0.08   0.936    -.0274192    .0297682
//   plantype_2 |   .0044946   .0160062     0.28   0.779    -.0268962    .0358853
//   plantype_3 |  -.0024867   .0151651    -0.16   0.870    -.0322279    .0272546
//        _cons |   .1152318    .011646     9.89   0.000     .0923921    .1380714
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,040
//                                                 F(3, 1557)        =       1.97
//                                                 Prob > F          =     0.1166
//                                                 R-squared         =     0.0024
//                                                 Root MSE          =     14.998
//
//                               (Std. err. adjusted for 1,558 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       ghindx | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -1.306369   .8708148    -1.50   0.134    -3.014463    .4017239
//   plantype_2 |  -1.440789   .9504384    -1.52   0.130    -3.305063    .4234851
//   plantype_3 |   .2106351   .9204692     0.23   0.819    -1.594855    2.016125
//        _cons |   70.85932   .6931129   102.23   0.000     69.49979    72.21886
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      2,254
//                                                 F(3, 1175)        =       1.38
//                                                 Prob > F          =     0.2481
//                                                 R-squared         =     0.0022
//                                                 Root MSE          =     42.872
//
//                               (Std. err. adjusted for 1,176 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//      cholest | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -5.246336   2.701373    -1.94   0.052    -10.54639    .0537178
//   plantype_2 |  -1.420108    2.98409    -0.48   0.634    -7.274848    4.434632
//   plantype_3 |  -1.931604   2.758279    -0.70   0.484    -7.343305    3.480097
//        _cons |   207.3021   1.990889   104.13   0.000      203.396    211.2082
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      2,292
//                                                 F(3, 1193)        =       1.37
//                                                 Prob > F          =     0.2494
//                                                 R-squared         =     0.0021
//                                                 Root MSE          =     16.577
//
//                               (Std. err. adjusted for 1,194 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       systol | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   1.123672   1.008422     1.11   0.265     -.854806     3.10215
//   plantype_2 |   2.323561     1.1545     2.01   0.044     .0584845    4.588637
//   plantype_3 |   .9073152   1.075802     0.84   0.399    -1.203359     3.01799
//        _cons |   122.3418   .8037472   152.21   0.000     120.7649    123.9187
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,817
//                                                 F(3, 1940)        =       1.46
//                                                 Prob > F          =     0.2228
//                                                 R-squared         =     0.0016
//                                                 Root MSE          =     13.846
//
//                               (Std. err. adjusted for 1,941 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//          mhi | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .8900588   .7652742     1.16   0.245    -.6107875    2.390905
//   plantype_2 |  -.1201439       .821    -0.15   0.884    -1.730279    1.489991
//   plantype_3 |   1.189266   .8094931     1.47   0.142    -.3983018    2.776834
//        _cons |   73.84584   .6181913   119.45   0.000     72.63346    75.05823
// ------------------------------------------------------------------------------
//
//   1,022
//
//
//
// --------------------------------------------------------------------------------
//                                     Cata. mean    Deduct - cata.  Coins - cata
// --------------------------------------------------------------------------------
//  Female                               0.5599         -0.0231        -0.0247
//                                      (0.4967)        (0.0160)       (0.0153)
//  Nonwhite                             0.1717         -0.0188        -0.0269
//                                      (0.3774)        (0.0266)       (0.0250)
//  Age                                  32.3610         0.5607         0.9658
//                                      (12.9233)       (0.6759)       (0.6547)
//  Education                            12.1048        -0.1568        -0.0613
//                                      (2.8815)        (0.1909)       (0.1855)
//  Family Income                      31,603.2072    -2,104.3855      969.7590
//                                    (18,148.2536)   (1,383.6913)   (1,389.0149)
//  Hospitalized last year               0.1152          0.0045        -0.0025
//                                      (0.3195)        (0.0160)       (0.0152)
//  General health index                 70.8593        -1.4408         0.2106
//                                      (14.9112)       (0.9504)       (0.9205)
//  Cholesterol (mg/dl)                 207.3021        -1.4201        -1.9316
//                                      (39.9245)       (2.9841)       (2.7583)
//  Systolic blood pressure (mm Hg)     122.3418         2.3236         0.9073
//                                      (16.4762)       (1.1545)       (1.0758)
//  Mental health index                  73.8458        -0.1201         1.1893
//                                      (14.2508)       (0.8210)       (0.8095)
//  Number enrolled                     759.0000        881.0000      1,022.0000
//
// --------------------------------------------------------------------------------

// %%
* Column 4: Coinsurance plan compared to catastrophic plan
matrix free_diff = J(11, 2, .)
local row = 1

foreach var of varlist female blackhisp age educper income1cpi hosp ghindx cholest systol mhi {
	reg `var' plantype_1 plantype_2 plantype_3, cl(famid)
	matrix free_diff[`row', 1] = _b[plantype_1]
	matrix free_diff[`row', 2] = _se[plantype_1]
	local row = `row'+1
}

count if plantype_1 == 1
matrix free_diff[11, 1] = r(N)

#d ;
frmttable, statmat(free_diff) varlabels sdec(4)
		   ctitle("Free - cata.") substat(1) merge;
#d cr
// Out:
// Linear regression                               Number of obs     =      3,957
//                                                 F(3, 1982)        =       2.14
//                                                 Prob > F          =     0.0935
//                                                 R-squared         =     0.0007
//                                                 Root MSE          =     .49878
//
//                               (Std. err. adjusted for 1,983 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       female | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.0379396   .0149991    -2.53   0.012    -.0673552   -.0085239
//   plantype_2 |  -.0230574   .0160171    -1.44   0.150    -.0544694    .0083546
//   plantype_3 |  -.0247223    .015326    -1.61   0.107     -.054779    .0053345
//        _cons |   .5599473   .0117928    47.48   0.000     .5368198    .5830748
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,131
//                                                 F(3, 1966)        =       0.51
//                                                 Prob > F          =     0.6757
//                                                 R-squared         =     0.0009
//                                                 Root MSE          =      .3585
//
//                               (Std. err. adjusted for 1,967 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//    blackhisp | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.0280873   .0245338    -1.14   0.252    -.0762023    .0200277
//   plantype_2 |  -.0187915   .0265551    -0.71   0.479    -.0708705    .0332875
//   plantype_3 |   -.026914   .0249592    -1.08   0.281    -.0758632    .0220353
//        _cons |   .1716667   .0198612     8.64   0.000     .1327154     .210618
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,956
//                                                 F(3, 1982)        =       0.74
//                                                 Prob > F          =     0.5261
//                                                 R-squared         =     0.0006
//                                                 Root MSE          =     13.199
//
//                               (Std. err. adjusted for 1,983 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//          age | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .4349801   .6139501     0.71   0.479    -.7690751    1.639035
//   plantype_2 |   .5606786   .6758793     0.83   0.407      -.76483    1.886187
//   plantype_3 |   .9658089    .654734     1.48   0.140    -.3182304    2.249848
//        _cons |     32.361   .4849485    66.73   0.000     31.40994    33.31206
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,468
//                                                 F(3, 1975)        =       0.83
//                                                 Prob > F          =     0.4753
//                                                 R-squared         =     0.0012
//                                                 Root MSE          =     2.9817
//
//                               (Std. err. adjusted for 1,976 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//      educper | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -.2627213   .1827742    -1.44   0.151    -.6211718    .0957292
//   plantype_2 |  -.1567911   .1908755    -0.82   0.411    -.5311296    .2175475
//   plantype_3 |  -.0612511   .1855042    -0.33   0.741    -.4250557    .3025534
//        _cons |   12.10483   .1400629    86.42   0.000     11.83014    12.37951
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,742
//                                                 F(3, 1883)        =       2.21
//                                                 Prob > F          =     0.0851
//                                                 R-squared         =     0.0041
//                                                 Root MSE          =      17425
//
//                               (Std. err. adjusted for 1,884 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//   income1cpi | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -976.1847   1344.553    -0.73   0.468    -3613.154    1660.785
//   plantype_2 |  -2104.385   1383.691    -1.52   0.128    -4818.115    609.3439
//   plantype_3 |    969.759   1389.015     0.70   0.485    -1754.411    3693.929
//        _cons |   31603.21   1071.181    29.50   0.000     29502.38    33704.03
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,932
//                                                 F(3, 1976)        =       0.08
//                                                 Prob > F          =     0.9720
//                                                 R-squared         =     0.0001
//                                                 Root MSE          =     .32034
//
//                               (Std. err. adjusted for 1,977 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//         hosp | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .0011745     .01458     0.08   0.936    -.0274192    .0297682
//   plantype_2 |   .0044946   .0160062     0.28   0.779    -.0268962    .0358853
//   plantype_3 |  -.0024867   .0151651    -0.16   0.870    -.0322279    .0272546
//        _cons |   .1152318    .011646     9.89   0.000     .0923921    .1380714
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,040
//                                                 F(3, 1557)        =       1.97
//                                                 Prob > F          =     0.1166
//                                                 R-squared         =     0.0024
//                                                 Root MSE          =     14.998
//
//                               (Std. err. adjusted for 1,558 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       ghindx | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -1.306369   .8708148    -1.50   0.134    -3.014463    .4017239
//   plantype_2 |  -1.440789   .9504384    -1.52   0.130    -3.305063    .4234851
//   plantype_3 |   .2106351   .9204692     0.23   0.819    -1.594855    2.016125
//        _cons |   70.85932   .6931129   102.23   0.000     69.49979    72.21886
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      2,254
//                                                 F(3, 1175)        =       1.38
//                                                 Prob > F          =     0.2481
//                                                 R-squared         =     0.0022
//                                                 Root MSE          =     42.872
//
//                               (Std. err. adjusted for 1,176 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//      cholest | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |  -5.246336   2.701373    -1.94   0.052    -10.54639    .0537178
//   plantype_2 |  -1.420108    2.98409    -0.48   0.634    -7.274848    4.434632
//   plantype_3 |  -1.931604   2.758279    -0.70   0.484    -7.343305    3.480097
//        _cons |   207.3021   1.990889   104.13   0.000      203.396    211.2082
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      2,292
//                                                 F(3, 1193)        =       1.37
//                                                 Prob > F          =     0.2494
//                                                 R-squared         =     0.0021
//                                                 Root MSE          =     16.577
//
//                               (Std. err. adjusted for 1,194 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       systol | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   1.123672   1.008422     1.11   0.265     -.854806     3.10215
//   plantype_2 |   2.323561     1.1545     2.01   0.044     .0584845    4.588637
//   plantype_3 |   .9073152   1.075802     0.84   0.399    -1.203359     3.01799
//        _cons |   122.3418   .8037472   152.21   0.000     120.7649    123.9187
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,817
//                                                 F(3, 1940)        =       1.46
//                                                 Prob > F          =     0.2228
//                                                 R-squared         =     0.0016
//                                                 Root MSE          =     13.846
//
//                               (Std. err. adjusted for 1,941 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//          mhi | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//   plantype_1 |   .8900588   .7652742     1.16   0.245    -.6107875    2.390905
//   plantype_2 |  -.1201439       .821    -0.15   0.884    -1.730279    1.489991
//   plantype_3 |   1.189266   .8094931     1.47   0.142    -.3983018    2.776834
//        _cons |   73.84584   .6181913   119.45   0.000     72.63346    75.05823
// ------------------------------------------------------------------------------
//
//   1,295
//
//
//
// --------------------------------------------------------------------------------
//                                     Cata. mean    Deduct - cata.  Coins - cata
// --------------------------------------------------------------------------------
//  Female                               0.5599         -0.0231        -0.0247
//                                      (0.4967)        (0.0160)       (0.0153)
//  Nonwhite                             0.1717         -0.0188        -0.0269
//                                      (0.3774)        (0.0266)       (0.0250)
//  Age                                  32.3610         0.5607         0.9658
//                                      (12.9233)       (0.6759)       (0.6547)
//  Education                            12.1048        -0.1568        -0.0613
//                                      (2.8815)        (0.1909)       (0.1855)
//  Family Income                      31,603.2072    -2,104.3855      969.7590
//                                    (18,148.2536)   (1,383.6913)   (1,389.0149)
//  Hospitalized last year               0.1152          0.0045        -0.0025
//                                      (0.3195)        (0.0160)       (0.0152)
//  General health index                 70.8593        -1.4408         0.2106
//                                      (14.9112)       (0.9504)       (0.9205)
//  Cholesterol (mg/dl)                 207.3021        -1.4201        -1.9316
//                                      (39.9245)       (2.9841)       (2.7583)
//  Systolic blood pressure (mm Hg)     122.3418         2.3236         0.9073
//                                      (16.4762)       (1.1545)       (1.0758)
//  Mental health index                  73.8458        -0.1201         1.1893
//                                      (14.2508)       (0.8210)       (0.8095)
//  Number enrolled                     759.0000        881.0000      1,022.0000
//
// --------------------------------------------------------------------------------
//
//
//                -------------------------------------------------
//                                                   Free - cata.
//                -------------------------------------------------
//                 Female                              -0.0379
//                                                     (0.0150)
//                 Nonwhite                            -0.0281
//                                                     (0.0245)
//                 Age                                  0.4350
//                                                     (0.6140)
//                 Education                           -0.2627
//                                                     (0.1828)
//                 Family Income                      -976.1847
//                                                   (1,344.5526)
//                 Hospitalized last year               0.0012
//                                                     (0.0146)
//                 General health index                -1.3064
//                                                     (0.8708)
//                 Cholesterol (mg/dl)                 -5.2463
//                                                     (2.7014)
//                 Systolic blood pressure (mm Hg)      1.1237
//                                                     (1.0084)
//                 Mental health index                  0.8901
//                                                     (0.7653)
//                 Number enrolled                    1,295.0000
//
//                -------------------------------------------------

// %%
* Column 5: Any insurance plan compared to catastrophic plan
matrix any_diff = J(11, 2, .)
local row = 1

foreach var of varlist female blackhisp age educper income1cpi hosp ghindx cholest systol mhi {
	reg `var' any_ins, cl(famid)
	matrix any_diff[`row', 1] = _b[any_ins]
	matrix any_diff[`row', 2] = _se[any_ins]
	local row = `row'+1
}

count if any_ins == 1
matrix any_diff[11, 1] = r(N)

#d ;
frmttable, statmat(any_diff) varlabels sdec(4)
		   ctitle("Any - cata.") substat(1) merge;
#d cr
// Out:
// Linear regression                               Number of obs     =      3,957
//                                                 F(1, 1982)        =       5.11
//                                                 Prob > F          =     0.0240
//                                                 R-squared         =     0.0005
//                                                 Root MSE          =     .49869
//
//                               (Std. err. adjusted for 1,983 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       female | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |  -.0296158   .0131065    -2.26   0.024    -.0553198   -.0039118
//        _cons |   .5599473   .0117898    47.49   0.000     .5368256     .583069
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,131
//                                                 F(1, 1966)        =       1.32
//                                                 Prob > F          =     0.2499
//                                                 R-squared         =     0.0008
//                                                 Root MSE          =     .35841
//
//                               (Std. err. adjusted for 1,967 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//    blackhisp | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |  -.0250843   .0217955    -1.15   0.250    -.0678289    .0176603
//        _cons |   .1716667   .0198549     8.65   0.000     .1327278    .2106055
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,956
//                                                 F(1, 1982)        =       1.39
//                                                 Prob > F          =     0.2392
//                                                 R-squared         =     0.0004
//                                                 Root MSE          =     13.197
//
//                               (Std. err. adjusted for 1,983 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//          age | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |   .6393115   .5430258     1.18   0.239    -.4256498    1.704273
//        _cons |     32.361   .4848258    66.75   0.000     31.41018    33.31182
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,468
//                                                 F(1, 1975)        =       1.15
//                                                 Prob > F          =     0.2829
//                                                 R-squared         =     0.0005
//                                                 Root MSE          =     2.9819
//
//                               (Std. err. adjusted for 1,976 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//      educper | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |  -.1686412   .1570166    -1.07   0.283    -.4765767    .1392944
//        _cons |   12.10483   .1400225    86.45   0.000     11.83022    12.37943
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,742
//                                                 F(1, 1883)        =       0.31
//                                                 Prob > F          =     0.5800
//                                                 R-squared         =     0.0002
//                                                 Root MSE          =      17455
//
//                               (Std. err. adjusted for 1,884 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//   income1cpi | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |  -653.6261    1181.03    -0.55   0.580    -2969.892    1662.639
//        _cons |   31603.21   1070.894    29.51   0.000     29502.94    33703.47
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,932
//                                                 F(1, 1976)        =       0.01
//                                                 Prob > F          =     0.9435
//                                                 R-squared         =     0.0000
//                                                 Root MSE          =     .32027
//
//                               (Std. err. adjusted for 1,977 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//         hosp | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |   .0009155   .0129191     0.07   0.944    -.0244209    .0262519
//        _cons |   .1152318    .011643     9.90   0.000     .0923979    .1380656
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,040
//                                                 F(1, 1557)        =       1.44
//                                                 Prob > F          =     0.2310
//                                                 R-squared         =     0.0005
//                                                 Root MSE          =     15.007
//
//                               (Std. err. adjusted for 1,558 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       ghindx | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |  -.9253643   .7722345    -1.20   0.231    -2.440094     .589365
//        _cons |   70.85932   .6928847   102.27   0.000     69.50024    72.21841
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      2,254
//                                                 F(1, 1175)        =       1.93
//                                                 Prob > F          =     0.1647
//                                                 R-squared         =     0.0008
//                                                 Root MSE          =     42.883
//
//                               (Std. err. adjusted for 1,176 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//      cholest | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |  -3.190449    2.29487    -1.39   0.165    -7.692949     1.31205
//        _cons |   207.3021   1.990005   104.17   0.000     203.3977    211.2065
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      2,292
//                                                 F(1, 1193)        =       2.37
//                                                 Prob > F          =     0.1236
//                                                 R-squared         =     0.0011
//                                                 Root MSE          =     16.578
//
//                               (Std. err. adjusted for 1,194 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//       systol | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |   1.387623   .9006257     1.54   0.124    -.3793636     3.15461
//        _cons |   122.3418   .8033961   152.28   0.000     120.7656     123.918
// ------------------------------------------------------------------------------
//
// Linear regression                               Number of obs     =      3,817
//                                                 F(1, 1940)        =       1.07
//                                                 Prob > F          =     0.3004
//                                                 R-squared         =     0.0004
//                                                 Root MSE          =     13.851
//
//                               (Std. err. adjusted for 1,941 clusters in famid)
// ------------------------------------------------------------------------------
//              |               Robust
//          mhi | Coefficient  std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//      any_ins |   .7067562   .6822966     1.04   0.300    -.6313554    2.044868
//        _cons |   73.84584   .6180292   119.49   0.000     72.63377    75.05792
// ------------------------------------------------------------------------------
//
//   3,198
//
//
//
// --------------------------------------------------------------------------------
//                                     Cata. mean    Deduct - cata.  Coins - cata
// --------------------------------------------------------------------------------
//  Female                               0.5599         -0.0231        -0.0247
//                                      (0.4967)        (0.0160)       (0.0153)
//  Nonwhite                             0.1717         -0.0188        -0.0269
//                                      (0.3774)        (0.0266)       (0.0250)
//  Age                                  32.3610         0.5607         0.9658
//                                      (12.9233)       (0.6759)       (0.6547)
//  Education                            12.1048        -0.1568        -0.0613
//                                      (2.8815)        (0.1909)       (0.1855)
//  Family Income                      31,603.2072    -2,104.3855      969.7590
//                                    (18,148.2536)   (1,383.6913)   (1,389.0149)
//  Hospitalized last year               0.1152          0.0045        -0.0025
//                                      (0.3195)        (0.0160)       (0.0152)
//  General health index                 70.8593        -1.4408         0.2106
//                                      (14.9112)       (0.9504)       (0.9205)
//  Cholesterol (mg/dl)                 207.3021        -1.4201        -1.9316
//                                      (39.9245)       (2.9841)       (2.7583)
//  Systolic blood pressure (mm Hg)     122.3418         2.3236         0.9073
//                                      (16.4762)       (1.1545)       (1.0758)
//  Mental health index                  73.8458        -0.1201         1.1893
//                                      (14.2508)       (0.8210)       (0.8095)
//  Number enrolled                     759.0000        881.0000      1,022.0000
//
// --------------------------------------------------------------------------------
//
//
//         ---------------------------------------------------------------
//                                            Free - cata.  Any - cata.
//         ---------------------------------------------------------------
//          Female                              -0.0379       -0.0296
//                                              (0.0150)      (0.0131)
//          Nonwhite                            -0.0281       -0.0251
//                                              (0.0245)      (0.0218)
//          Age                                  0.4350        0.6393
//                                              (0.6140)      (0.5430)
//          Education                           -0.2627       -0.1686
//                                              (0.1828)      (0.1570)
//          Family Income                      -976.1847     -653.6261
//                                            (1,344.5526)  (1,181.0302)
//          Hospitalized last year               0.0012        0.0009
//                                              (0.0146)      (0.0129)
//          General health index                -1.3064       -0.9254
//                                              (0.8708)      (0.7722)
//          Cholesterol (mg/dl)                 -5.2463       -3.1904
//                                              (2.7014)      (2.2949)
//          Systolic blood pressure (mm Hg)      1.1237        1.3876
//                                              (1.0084)      (0.9006)
//          Mental health index                  0.8901        0.7068
//                                              (0.7653)      (0.6823)
//          Number enrolled                    1,295.0000    3,198.0000
//
//         ---------------------------------------------------------------

// %% [markdown]
// # Exercise: Recreate Panel A in Table I in Miguel & Kremer

// %%
use namelist.dta, clear 

keep if visit==981 
	collapse sex elg98 stdgap yrbirth wgrp* (count) np=pupid, by (sch98v1) 

label var sex "Male"
label var elg98 "Proportion girls"
label var stdgap "Grade"
label var yrbirth "Year of Birth"
// Out:
// (521,880 observations deleted)

// %%
matrix drop _all
mata: mata clear

*Columns 1-3
forvalues g = 1/3{

matrix mean_dep_`g' = J(4,2,.)
local i = 1	

foreach var of varlist sex elg98 stdgap yrbirth{
	
	summ `var' [aw=np] if wgrp == `g'
	matrix mean_dep_`g'[`i',1] = r(mean)
	matrix rownames mean_dep_`g' =  sex elg98 stdgap yrbirth
	local i = `i' + 1
}
frmttable, statmat(mean_dep_`g') substat(1) ctitle("","Group `g'")  varlabels merge
}
// Out:
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11639    .5330215   .0274975   .4649681        .58
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//        elg98 |      25       11639     .885924   .0247143   .8320313   .9418604
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//       stdgap |      25       11639   -1.972652   .2533067  -2.605882  -1.580786
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//      yrbirth |      25       11639    1986.192   .5346503   1985.256   1987.464
// warning: no existing table found for merge or append
//
//                          ------------------------------
//                                              Group 1
//                          ------------------------------
//                           Male                 0.53
//
//                           Proportion girls     0.89
//
//                           Grade               -1.97
//
//                           Year of Birth      1,986.19
//
//                          ------------------------------
//
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11995    .5095843   .1047281   .0200893   .5714286
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//        elg98 |      25       11995    .8919841    .024791   .8363096          1
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//       stdgap |      25       11995   -1.822477   .3956333  -2.539063  -.7777778
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//      yrbirth |      25       11995    1986.542   .6205696   1985.349   1988.789
//
//                     ----------------------------------------
//                                         Group 1   Group 2
//                     ----------------------------------------
//                      Male                 0.53      0.51
//
//                      Proportion girls     0.89      0.89
//
//                      Grade               -1.97     -1.82
//
//                      Year of Birth      1,986.19  1,986.54
//
//                     ----------------------------------------
//
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//          sex |      25       11158    .5221577   .0213547   .4585635   .5606061
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//        elg98 |      25       11158    .8842172   .0199678        .84   .9104478
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//       stdgap |      25       11158    -1.96956    .335091  -2.612903  -1.384921
//
//     Variable |     Obs      Weight        Mean   Std. dev.       Min        Max
// -------------+-----------------------------------------------------------------
//      yrbirth |      25       11158    1985.787   .5751849   1984.777   1986.964
//
//                --------------------------------------------------
//                                    Group 1   Group 2   Group 3
//                --------------------------------------------------
//                 Male                 0.53      0.51      0.52
//
//                 Proportion girls     0.89      0.89      0.88
//
//                 Grade               -1.97     -1.82     -1.97
//
//                 Year of Birth      1,986.19  1,986.54  1,985.79
//
//                --------------------------------------------------

// %%
* Column 4

matrix control_diff_1 = J(4,2,.)
local row = 1

foreach var in sex elg98 stdgap yrbirth { 
	regress `var' wgrp1 wgrp2 [aw=np] 
	matrix control_diff_1[`row',1] = _b[wgrp1]
	matrix control_diff_1[`row',2] = _se[wgrp1]
	local row = `row' + 1
} 

matrix list control_diff_1

frmttable, statmat(control_diff_1) substat(1) ctitle("Group 1 - Group 3") merge
// Out:
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      0.84
//        Model |  .007012123         2  .003506062   Prob > F        =    0.4365
//     Residual |  .300999144        72  .004180544   R-squared       =    0.0228
// -------------+----------------------------------   Adj R-squared   =   -0.0044
//        Total |  .308011268        74  .004162314   Root MSE        =    .06466
//
// ------------------------------------------------------------------------------
//          sex | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |   .0108639   .0184507     0.59   0.558    -.0259169    .0476447
//        wgrp2 |  -.0125733   .0183162    -0.69   0.495     -.049086    .0239394
//        _cons |   .5221577   .0131835    39.61   0.000     .4958767    .5484386
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      0.77
//        Model |  .000841356         2  .000420678   Prob > F        =    0.4653
//     Residual |  .039174487        72   .00054409   R-squared       =    0.0210
// -------------+----------------------------------   Adj R-squared   =   -0.0062
//        Total |  .040015843        74  .000540755   Root MSE        =    .02333
//
// ------------------------------------------------------------------------------
//        elg98 | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |   .0017069   .0066563     0.26   0.798    -.0115622    .0149759
//        wgrp2 |   .0077669   .0066078     1.18   0.244    -.0054054    .0209393
//        _cons |   .8842172   .0047561   185.91   0.000     .8747361    .8936983
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      1.68
//        Model |  .374551628         2  .187275814   Prob > F        =    0.1935
//     Residual |  8.02368227        72  .111440031   R-squared       =    0.0446
// -------------+----------------------------------   Adj R-squared   =    0.0181
//        Total |   8.3982339        74  .113489647   Root MSE        =    .33383
//
// ------------------------------------------------------------------------------
//       stdgap | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |  -.0030915   .0952615    -0.03   0.974    -.1929918    .1868089
//        wgrp2 |   .1470828   .0945671     1.56   0.124    -.0414332    .3355989
//        _cons |   -1.96956    .068067   -28.94   0.000    -2.105249   -1.833871
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =     10.63
//        Model |  7.10907992         2  3.55453996   Prob > F        =    0.0001
//     Residual |  24.0838656        72  .334498133   R-squared       =    0.2279
// -------------+----------------------------------   Adj R-squared   =    0.2065
//        Total |  31.1929455        74   .42152629   Root MSE        =    .57836
//
// ------------------------------------------------------------------------------
//      yrbirth | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |    .404556   .1650417     2.45   0.017     .0755514    .7335607
//        wgrp2 |   .7551539   .1638386     4.61   0.000     .4285476     1.08176
//        _cons |   1985.787   .1179269  1.7e+04   0.000     1985.552    1986.022
// ------------------------------------------------------------------------------
//
//
// control_diff_1[4,2]
//             c1          c2
// r1    .0108639   .01845072
// r2   .00170685   .00665629
// r3  -.00309147   .09526152
// r4   .40455604   .16504172
//
//
//      ---------------------------------------------------------------------
//                          Group 1   Group 2   Group 3   Group 1 - Group 3
//      ---------------------------------------------------------------------
//       Male                 0.53      0.51      0.52          0.01
//                                                             (0.02)
//       Proportion girls     0.89      0.89      0.88          0.00
//                                                             (0.01)
//       Grade               -1.97     -1.82     -1.97          -0.00
//                                                             (0.10)
//       Year of Birth      1,986.19  1,986.54  1,985.79        0.40
//                                                             (0.17)
//      ---------------------------------------------------------------------

// %%
* Column 5

matrix control_diff_2 = J(4,2,.)
local row = 1

foreach var in sex elg98 stdgap yrbirth { 
	regress `var' wgrp1 wgrp2 [aw=np] 
	matrix control_diff_2[`row',1] = _b[wgrp2]
	matrix control_diff_2[`row',2] = _se[wgrp2]
	local row = `row' + 1
} 

matrix list control_diff_2

frmttable, statmat(control_diff_2) substat(1) ctitle("Group 2 - Group 3")  merge
// Out:
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      0.84
//        Model |  .007012123         2  .003506062   Prob > F        =    0.4365
//     Residual |  .300999144        72  .004180544   R-squared       =    0.0228
// -------------+----------------------------------   Adj R-squared   =   -0.0044
//        Total |  .308011268        74  .004162314   Root MSE        =    .06466
//
// ------------------------------------------------------------------------------
//          sex | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |   .0108639   .0184507     0.59   0.558    -.0259169    .0476447
//        wgrp2 |  -.0125733   .0183162    -0.69   0.495     -.049086    .0239394
//        _cons |   .5221577   .0131835    39.61   0.000     .4958767    .5484386
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      0.77
//        Model |  .000841356         2  .000420678   Prob > F        =    0.4653
//     Residual |  .039174487        72   .00054409   R-squared       =    0.0210
// -------------+----------------------------------   Adj R-squared   =   -0.0062
//        Total |  .040015843        74  .000540755   Root MSE        =    .02333
//
// ------------------------------------------------------------------------------
//        elg98 | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |   .0017069   .0066563     0.26   0.798    -.0115622    .0149759
//        wgrp2 |   .0077669   .0066078     1.18   0.244    -.0054054    .0209393
//        _cons |   .8842172   .0047561   185.91   0.000     .8747361    .8936983
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =      1.68
//        Model |  .374551628         2  .187275814   Prob > F        =    0.1935
//     Residual |  8.02368227        72  .111440031   R-squared       =    0.0446
// -------------+----------------------------------   Adj R-squared   =    0.0181
//        Total |   8.3982339        74  .113489647   Root MSE        =    .33383
//
// ------------------------------------------------------------------------------
//       stdgap | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |  -.0030915   .0952615    -0.03   0.974    -.1929918    .1868089
//        wgrp2 |   .1470828   .0945671     1.56   0.124    -.0414332    .3355989
//        _cons |   -1.96956    .068067   -28.94   0.000    -2.105249   -1.833871
// ------------------------------------------------------------------------------
// (sum of wgt is 34,792)
//
//       Source |       SS           df       MS      Number of obs   =        75
// -------------+----------------------------------   F(2, 72)        =     10.63
//        Model |  7.10907992         2  3.55453996   Prob > F        =    0.0001
//     Residual |  24.0838656        72  .334498133   R-squared       =    0.2279
// -------------+----------------------------------   Adj R-squared   =    0.2065
//        Total |  31.1929455        74   .42152629   Root MSE        =    .57836
//
// ------------------------------------------------------------------------------
//      yrbirth | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
// -------------+----------------------------------------------------------------
//        wgrp1 |    .404556   .1650417     2.45   0.017     .0755514    .7335607
//        wgrp2 |   .7551539   .1638386     4.61   0.000     .4285476     1.08176
//        _cons |   1985.787   .1179269  1.7e+04   0.000     1985.552    1986.022
// ------------------------------------------------------------------------------
//
//
// control_diff_2[4,2]
//            c1         c2
// r1  -.0125733  .01831622
// r2   .0077669  .00660777
// r3  .14708283  .09456709
// r4  .75515389  .16383861
//
//
//      ---------------------------------------------------------------------
//                          Group 1   Group 2   Group 3   Group 1 - Group 3
//      ---------------------------------------------------------------------
//       Male                 0.53      0.51      0.52          0.01
//                                                             (0.02)
//       Proportion girls     0.89      0.89      0.88          0.00
//                                                             (0.01)
//       Grade               -1.97     -1.82     -1.97          -0.00
//                                                             (0.10)
//       Year of Birth      1,986.19  1,986.54  1,985.79        0.40
//                                                             (0.17)
//      ---------------------------------------------------------------------
//
//
//                     ---------------------------------------
//                                         Group 2 - Group 3
//                     ---------------------------------------
//                      Male                     -0.01
//                                              (0.02)
//                      Proportion girls         0.01
//                                              (0.01)
//                      Grade                    0.15
//                                              (0.09)
//                      Year of Birth            0.76
//                                              (0.16)
//                     ---------------------------------------
